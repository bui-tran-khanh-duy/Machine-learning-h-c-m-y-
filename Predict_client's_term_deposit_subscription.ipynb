# %%
# %matplotlib inline
#Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

#Data processing Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


from sklearn.preprocessing import StandardScaler
# 10000, 1, 100
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier,plot_tree,export_text
from sklearn.metrics import accuracy_score, confusion_matrix


from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/bank-additional-full.csv",delimiter=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# **Column statistics**

# %%
df.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# duration        41188.0   258.285010  259.279249     0.000   102.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# pdays            999.000   999.000   999.000
# previous           0.000     0.000     7.000
# emp.var.rate       1.100     1.400     1.400
# cons.price.idx    93.749    93.994    94.767
# cons.conf.idx    -41.800   -36.400   -26.900
# euribor3m          4.857     4.961     5.045
# nr.employed     5191.000  5228.100  5228.100

# %% [markdown]
# **Kiểm tra giá trị null**

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df = df.drop_duplicates()

# %%
df = df.drop_duplicates()

# %%
plt.figure(figsize=(15,8))
plt.title('Count of Class')
sns.countplot(data=df, x='y')
# Out:
# <Axes: title={'center': 'Count of Class'}, xlabel='y', ylabel='count'>

# %%
corr_matrix = df.corr()
#ma trận tương quan
# sử dụng ma trận tương quan (Correlation Matrix) để kết hợp các biến lại với nhau
# Out:
# <ipython-input-179-78833acfa8cd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000808  0.004622 -0.034381  0.024379
# duration       -0.000808  1.000000 -0.071765 -0.047556  0.020600
# campaign        0.004622 -0.071765  1.000000  0.052606 -0.079182
# pdays          -0.034381 -0.047556  0.052606  1.000000 -0.587508
# previous        0.024379  0.020600 -0.079182 -0.587508  1.000000
# emp.var.rate   -0.000242 -0.027941  0.150786  0.271063 -0.420587
# cons.price.idx  0.001009  0.005303  0.127826  0.078920 -0.203197
# cons.conf.idx   0.129075 -0.008126 -0.013657 -0.091374 -0.050929
# euribor3m       0.010852 -0.032861  0.135169  0.296946 -0.454571
# nr.employed    -0.017607 -0.044672  0.144129  0.372659 -0.501411
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000242        0.001009       0.129075   0.010852
# duration           -0.027941        0.005303      -0.008126  -0.032861
# campaign            0.150786        0.127826      -0.013657   0.135169
# pdays               0.271063        0.078920      -0.091374   0.296946
# previous           -0.420587       -0.203197      -0.050929  -0.454571
# emp.var.rate        1.000000        0.775293       0.196257   0.972244
# cons.price.idx      0.775293        1.000000       0.059170   0.688180
# cons.conf.idx       0.196257        0.059170       1.000000   0.277864
# euribor3m           0.972244        0.688180       0.277864   1.000000
# nr.employed         0.906949        0.521945       0.100679   0.945146
#
#                 nr.employed
# age               -0.017607
# duration          -0.044672
# campaign           0.144129
# pdays              0.372659
# previous          -0.501411
# emp.var.rate       0.906949
# cons.price.idx     0.521945
# cons.conf.idx      0.100679
# euribor3m          0.945146
# nr.employed        1.000000

# %%
plt.figure(figsize = (12, 5))
sns.heatmap(corr_matrix,
            annot = True,
            cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **Categorizing variables**

# %%
df['y']= df['y'].replace('yes',1)
df['y']= df['y'].replace('no',0)
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed  y
# 0           5191.0  0
# 1           5191.0  0
# 2           5191.0  0
# 3           5191.0  0
# 4           5191.0  0
# ...            ... ..
# 41183       4963.6  1
# 41184       4963.6  0
# 41185       4963.6  0
# 41186       4963.6  1
# 41187       4963.6  0
#
# [41176 rows x 21 columns]

# %% [markdown]
# **Categorical**

# %%
num_col = [col for col in df.columns if df[col].dtype != 'object']
cat_col = [col for col in df.columns if df[col].dtype == 'object']

# %% [markdown]
# **Categorical variables**

# %%
cat_col
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %% [markdown]
# **Numerical variables**

# %%
num_col
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %% [markdown]
# **Visualizing Data**

# %% [markdown]
# *Numerical data *

# %%
fig,axes = plt.subplots(5,2,figsize=(20,35))
for index,col in enumerate(num_col[:-1]):
  x,y = index//2,index%2
  sns.histplot(df[col],ax=axes[x,y])
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# *Categorical data *

# %%
fig, axes = plt.subplots(5, 2, figsize=(20, 45))

for index, col in enumerate(cat_col):
    x, y = index // 2, index % 2
    g = sns.countplot(data=df, x=col, ax=axes[x, y])
    g.set_xticklabels(g.get_xticklabels(), rotation=30)

plt.subplots_adjust(hspace=0.3)

# %% [markdown]
# **Outliers**

# %% [markdown]
# **Visualizing**

# %%
fig,axes = plt.subplots(3,4,figsize=(20,20))
for index,col in enumerate(num_col):
    x,y = index//4, index%4
    sns.boxplot(df[col],ax=axes[x,y])
plt.subplots_adjust(hspace=0.5)

# %%
X = df.drop('y', axis=1)
y = df['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Modeling**

# %% [markdown]
# **descion tree**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Áp dụng One-Hot Encoding cho tập huấn luyện và tập kiểm tra
X_train_encoded = pd.get_dummies(X_train)
X_test_encoded = pd.get_dummies(X_test)

# Đảm bảo rằng tập kiểm tra có cùng số lượng cột và cùng tên cột với tập huấn luyện
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)

# Initialize the Decision Tree classifier
dt_classifier = DecisionTreeClassifier(max_depth=3, random_state=42)

# Huấn luyện mô hình trên tập huấn luyện đã được mã hóa
dt_classifier.fit(X_train_encoded, y_train)

# Dự đoán trên tập kiểm tra đã được mã hóa
y_pred = dt_classifier.predict(X_test_encoded)

# Đánh giá độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print(f"Decision Tree Accuracy: {accuracy}")
# Out:
# Decision Tree Accuracy: 0.9051242613130414

# %% [markdown]
# độ chính xác của cây là 0.9051242613130414

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['0','1'], yticklabels=['0','1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# True Positive (số lượng các trường hợp dự đoán đúng là positive): là 10345
#
# False Positive (số lượng các trường hợp dự đoán sai là positive): là 584
#
# False Negative (số lượng các trường hợp dự đoán sai là Negative): là 588
#
# True Negative (số lượng các trường hợp dự đoán đúng là Negative): là 836

# %%
# Visualize the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_classifier, filled=True, feature_names=X_train_encoded.columns, class_names=['0', '1'])
plt.show()

# %%
# Tiền xử lý dữ liệu chuỗi bằng One-Hot Encoding
X_encoded = pd.get_dummies(X)  # Áp dụng One-Hot Encoding cho tất cả các biến chuỗi trong X

# Tách tập dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)

# Define a range of max_depth values to iterate over
max_depth_values = range(3, 20)  # You can adjust this range

# Initialize variables to keep track of the best max depth and corresponding score
best_max_depth = None
best_score = 0.0

# Iterate over different max_depth values
for max_depth in max_depth_values:
    # Initialize the DecisionTreeClassifier with the current max_depth
    clf = DecisionTreeClassifier(max_depth=max_depth, random_state=42)
    # Fit the model to the training data
    clf.fit(X_train, y_train)
    # Make predictions on the test data
    y_pred = clf.predict(X_test)
    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    # Print the accuracy for the current max_depth
    print(f"Max Depth = {max_depth}: Accuracy = {accuracy}")
    # Check if the current model has a better accuracy than the previous best
    if accuracy > best_score:
        best_score = accuracy
        best_max_depth = max_depth

# Print the best max depth and corresponding accuracy
print(f"Best Max Depth = {best_max_depth}: Best Accuracy = {best_score}")
# Out:
# Max Depth = 3: Accuracy = 0.9051242613130414
# Max Depth = 4: Accuracy = 0.9109528049866429
# Max Depth = 5: Accuracy = 0.9120051809277099
# Max Depth = 6: Accuracy = 0.9137051728325103
# Max Depth = 7: Accuracy = 0.9134623168461102
# Max Depth = 8: Accuracy = 0.9097385250546426
# Max Depth = 9: Accuracy = 0.9082004371407755
# Max Depth = 10: Accuracy = 0.9038290293855743
# Max Depth = 11: Accuracy = 0.9028576054399741
# Max Depth = 12: Accuracy = 0.9013195175261071
# Max Depth = 13: Accuracy = 0.898971909657573
# Max Depth = 14: Accuracy = 0.8955719258479722
# Max Depth = 15: Accuracy = 0.8945195499069052
# Max Depth = 16: Accuracy = 0.8923338460293047
# Max Depth = 17: Accuracy = 0.8926576540111714
# Max Depth = 18: Accuracy = 0.8904719501335708
# Max Depth = 19: Accuracy = 0.8910386141018376
# Best Max Depth = 6: Best Accuracy = 0.9137051728325103

# %% [markdown]
# vậy độ sâu tốt nhất của cây (Best Accuracy) là : 0.9137051728325103

# %%
# Tiền xử lý dữ liệu chuỗi bằng One-Hot Encoding
X_encoded = pd.get_dummies(X)  # Áp dụng One-Hot Encoding cho tất cả các biến chuỗi trong X

# Khởi tạo và huấn luyện mô hình Decision Tree
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_encoded, y)

# Export the text representation of the decision tree
tree_rules = export_text(clf, feature_names=X_encoded.columns.tolist())
print(tree_rules)
# Out:
# |--- nr.employed <= 5087.65
# |   |--- duration <= 172.50
# |   |   |--- poutcome_success <= 0.50
# |   |   |   |--- duration <= 123.50
# |   |   |   |   |--- duration <= 77.50
# |   |   |   |   |   |--- euribor3m <= 1.26
# |   |   |   |   |   |   |--- emp.var.rate <= -3.20
# |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |--- job_management <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- job_management >  0.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 69.50
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx <= 92.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx >  92.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- duration >  69.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |--- day_of_week_fri <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_of_week_fri >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- emp.var.rate >  -3.20
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- euribor3m >  1.26
# |   |   |   |   |   |   |--- duration <= 68.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- duration >  68.00
# |   |   |   |   |   |   |   |--- duration <= 69.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration >  69.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- duration >  77.50
# |   |   |   |   |   |--- previous <= 1.50
# |   |   |   |   |   |   |--- euribor3m <= 0.64
# |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- euribor3m >  0.64
# |   |   |   |   |   |   |   |--- cons.conf.idx <= -30.75
# |   |   |   |   |   |   |   |   |--- euribor3m <= 0.89
# |   |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- job_blue-collar <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- job_blue-collar >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 95.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration >  95.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- euribor3m >  0.89
# |   |   |   |   |   |   |   |   |   |--- campaign <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- campaign >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cons.conf.idx >  -30.75
# |   |   |   |   |   |   |   |   |--- age <= 25.50
# |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  25.50
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- previous >  1.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- duration >  123.50
# |   |   |   |   |--- emp.var.rate <= -1.75
# |   |   |   |   |   |--- age <= 65.50
# |   |   |   |   |   |   |--- age <= 22.50
# |   |   |   |   |   |   |   |--- poutcome_nonexistent <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- poutcome_nonexistent >  0.50
# |   |   |   |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |   |   |   |--- job_student <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- loan_no <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- loan_no >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- job_student >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  22.50
# |   |   |   |   |   |   |   |--- pdays <= 11.50
# |   |   |   |   |   |   |   |   |--- education_basic.9y <= 0.50
# |   |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- education_basic.9y >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- pdays >  11.50
# |   |   |   |   |   |   |   |   |--- contact_telephone <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cons.conf.idx <= -28.35
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 158.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- duration >  158.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- cons.conf.idx >  -28.35
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- contact_telephone >  0.50
# |   |   |   |   |   |   |   |   |   |--- education_illiterate <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- month_nov <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- month_nov >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- education_illiterate >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  65.50
# |   |   |   |   |   |   |--- month_sep <= 0.50
# |   |   |   |   |   |   |   |--- duration <= 154.50
# |   |   |   |   |   |   |   |   |--- month_apr <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 71.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration >  147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  71.50
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_tue <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_tue >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- month_apr >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration >  154.50
# |   |   |   |   |   |   |   |   |--- day_of_week_tue <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_of_week_tue >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_sep >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- emp.var.rate >  -1.75
# |   |   |   |   |   |--- pdays <= 7.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- pdays >  7.50
# |   |   |   |   |   |   |--- euribor3m <= 0.88
# |   |   |   |   |   |   |   |--- age <= 77.50
# |   |   |   |   |   |   |   |   |--- duration <= 166.00
# |   |   |   |   |   |   |   |   |   |--- age <= 40.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  40.00
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- duration >  166.00
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  77.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- euribor3m >  0.88
# |   |   |   |   |   |   |   |--- day_of_week_tue <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_of_week_tue >  0.50
# |   |   |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |   |   |--- emp.var.rate <= -1.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- emp.var.rate >  -1.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- campaign >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- poutcome_success >  0.50
# |   |   |   |--- duration <= 147.50
# |   |   |   |   |--- cons.price.idx <= 93.56
# |   |   |   |   |   |--- nr.employed <= 5020.50
# |   |   |   |   |   |   |--- housing_no <= 0.50
# |   |   |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |   |   |--- month_nov <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 31.50
# |   |   |   |   |   |   |   |   |   |   |--- job_management <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- job_management >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  31.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- month_nov >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |   |   |--- age <= 27.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  27.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- housing_no >  0.50
# |   |   |   |   |   |   |   |--- campaign <= 3.00
# |   |   |   |   |   |   |   |   |--- age <= 21.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  21.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 63.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- duration >  63.50
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.4y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.4y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- campaign >  3.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- nr.employed >  5020.50
# |   |   |   |   |   |   |--- duration <= 136.50
# |   |   |   |   |   |   |   |--- age <= 69.50
# |   |   |   |   |   |   |   |   |--- euribor3m <= 1.24
# |   |   |   |   |   |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  53.50
# |   |   |   |   |   |   |   |   |   |   |--- job_retired <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- job_retired >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- euribor3m >  1.24
# |   |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- loan_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- loan_yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  69.50
# |   |   |   |   |   |   |   |   |--- day_of_week_wed <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_of_week_wed >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- duration >  136.50
# |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |--- pdays <= 10.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- pdays >  10.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cons.price.idx >  93.56
# |   |   |   |   |   |--- duration <= 134.50
# |   |   |   |   |   |   |--- pdays <= 1.00
# |   |   |   |   |   |   |   |--- euribor3m <= 0.89
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- euribor3m >  0.89
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- pdays >  1.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- duration >  134.50
# |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |--- duration <= 140.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration >  140.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- duration >  147.50
# |   |   |   |   |--- duration <= 164.50
# |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |--- cons.price.idx <= 92.54
# |   |   |   |   |   |   |   |--- month_sep <= 0.50
# |   |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 149.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  149.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- month_sep >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cons.price.idx >  92.54
# |   |   |   |   |   |   |   |--- pdays <= 2.50
# |   |   |   |   |   |   |   |   |--- marital_divorced <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- marital_divorced >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- pdays >  2.50
# |   |   |   |   |   |   |   |   |--- job_blue-collar <= 0.50
# |   |   |   |   |   |   |   |   |   |--- month_mar <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- education_high.school <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- education_high.school >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- month_mar >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- job_blue-collar >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |--- job_admin. <= 0.50
# |   |   |   |   |   |   |   |--- duration <= 149.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration >  149.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- job_admin. >  0.50
# |   |   |   |   |   |   |   |--- pdays <= 5.00
# |   |   |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- campaign >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- pdays >  5.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- duration >  164.50
# |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |--- euribor3m <= 0.74
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- euribor3m >  0.74
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- duration >  172.50
# |   |   |--- pdays <= 16.50
# |   |   |   |--- campaign <= 6.50
# |   |   |   |   |--- nr.employed <= 5020.50
# |   |   |   |   |   |--- duration <= 213.50
# |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |--- euribor3m <= 1.04
# |   |   |   |   |   |   |   |   |--- education_basic.9y <= 0.50
# |   |   |   |   |   |   |   |   |   |--- pdays <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- pdays >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- education_basic.9y >  0.50
# |   |   |   |   |   |   |   |   |   |--- pdays <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- pdays >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- euribor3m >  1.04
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |--- month_apr <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- month_apr >  0.50
# |   |   |   |   |   |   |   |   |--- housing_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- housing_yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- duration >  213.50
# |   |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |   |--- previous <= 6.00
# |   |   |   |   |   |   |   |   |--- campaign <= 5.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 428.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 418.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- duration >  418.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- duration >  428.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 1484.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- duration >  1484.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- campaign >  5.50
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- previous >  6.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |   |--- month_apr <= 0.50
# |   |   |   |   |   |   |   |   |--- pdays <= 15.50
# |   |   |   |   |   |   |   |   |   |--- job_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_success <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_success >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- job_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- pdays >  15.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- month_apr >  0.50
# |   |   |   |   |   |   |   |   |--- pdays <= 8.50
# |   |   |   |   |   |   |   |   |   |--- job_housemaid <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job_housemaid >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- pdays >  8.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- nr.employed >  5020.50
# |   |   |   |   |   |--- job_unknown <= 0.50
# |   |   |   |   |   |   |--- previous <= 3.50
# |   |   |   |   |   |   |   |--- euribor3m <= 0.87
# |   |   |   |   |   |   |   |   |--- duration <= 345.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- duration >  345.00
# |   |   |   |   |   |   |   |   |   |--- duration <= 364.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- duration >  364.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- euribor3m >  0.87
# |   |   |   |   |   |   |   |   |--- age <= 64.50
# |   |   |   |   |   |   |   |   |   |--- age <= 21.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  21.50
# |   |   |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- age >  64.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- previous >  3.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- job_unknown >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- campaign >  6.50
# |   |   |   |   |--- marital_divorced <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- marital_divorced >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- pdays >  16.50
# |   |   |   |--- duration <= 250.50
# |   |   |   |   |--- duration <= 198.50
# |   |   |   |   |   |--- euribor3m <= 0.70
# |   |   |   |   |   |   |--- euribor3m <= 0.64
# |   |   |   |   |   |   |   |--- euribor3m <= 0.63
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- euribor3m >  0.63
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- euribor3m >  0.64
# |   |   |   |   |   |   |   |--- job_admin. <= 0.50
# |   |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |   |   |--- previous <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- previous >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- job_admin. >  0.50
# |   |   |   |   |   |   |   |   |--- poutcome_failure <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- poutcome_failure >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 49.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  49.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- euribor3m >  0.70
# |   |   |   |   |   |   |--- euribor3m <= 0.84
# |   |   |   |   |   |   |   |--- month_nov <= 0.50
# |   |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 71.50
# |   |   |   |   |   |   |   |   |   |   |--- default_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- default_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  71.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |   |--- previous <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- previous >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- month_nov >  0.50
# |   |   |   |   |   |   |   |   |--- age <= 66.50
# |   |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- job_self-employed <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- job_self-employed >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- marital_married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- marital_married >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  66.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- euribor3m >  0.84
# |   |   |   |   |   |   |   |--- age <= 75.00
# |   |   |   |   |   |   |   |   |--- age <= 49.00
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- contact_telephone <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- contact_telephone >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 1.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  1.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  49.00
# |   |   |   |   |   |   |   |   |   |--- month_jul <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- loan_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- loan_yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- month_jul >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  75.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- duration >  198.50
# |   |   |   |   |   |--- poutcome_failure <= 0.50
# |   |   |   |   |   |   |--- contact_cellular <= 0.50
# |   |   |   |   |   |   |   |--- month_aug <= 0.50
# |   |   |   |   |   |   |   |   |--- duration <= 234.50
# |   |   |   |   |   |   |   |   |   |--- age <= 49.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 228.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration >  228.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  49.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- duration >  234.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- month_aug >  0.50
# |   |   |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |   |   |--- marital_married <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- marital_married >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- contact_cellular >  0.50
# |   |   |   |   |   |   |   |--- euribor3m <= 0.72
# |   |   |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- campaign >  1.50
# |   |   |   |   |   |   |   |   |   |--- education_basic.6y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- education_basic.6y >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- euribor3m >  0.72
# |   |   |   |   |   |   |   |   |--- euribor3m <= 0.77
# |   |   |   |   |   |   |   |   |   |--- duration <= 216.00
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration >  216.00
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_fri <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_fri >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- euribor3m >  0.77
# |   |   |   |   |   |   |   |   |   |--- age <= 78.00
# |   |   |   |   |   |   |   |   |   |   |--- campaign <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- campaign >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- age >  78.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- poutcome_failure >  0.50
# |   |   |   |   |   |   |--- euribor3m <= 0.88
# |   |   |   |   |   |   |   |--- duration <= 203.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- duration >  203.50
# |   |   |   |   |   |   |   |   |--- duration <= 230.50
# |   |   |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx <= 92.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx >  92.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- nr.employed <= 5013.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- nr.employed >  5013.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- duration >  230.50
# |   |   |   |   |   |   |   |   |   |--- job_student <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 73.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- age >  73.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- job_student >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- euribor3m >  0.88
# |   |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 52.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  52.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- campaign >  1.50
# |   |   |   |   |   |   |   |   |--- euribor3m <= 0.90
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- euribor3m >  0.90
# |   |   |   |   |   |   |   |   |   |--- cons.conf.idx <= -50.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cons.conf.idx >  -50.15
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 214.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  214.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- duration >  250.50
# |   |   |   |   |--- cons.price.idx <= 92.68
# |   |   |   |   |   |--- euribor3m <= 0.74
# |   |   |   |   |   |   |--- job_entrepreneur <= 0.50
# |   |   |   |   |   |   |   |--- age <= 67.50
# |   |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |   |--- campaign <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- campaign >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- contact_telephone <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- contact_telephone >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- age >  67.50
# |   |   |   |   |   |   |   |   |--- previous <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- previous >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- euribor3m >  0.74
# |   |   |   |   |   |   |--- euribor3m <= 1.07
# |   |   |   |   |   |   |   |--- age <= 33.50
# |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.9y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.9y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  33.50
# |   |   |   |   |   |   |   |   |--- duration <= 324.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 310.50
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- duration >  310.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 79.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  79.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- duration >  324.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 1109.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 79.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- age >  79.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- duration >  1109.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- age >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- euribor3m >  1.07
# |   |   |   |   |   |   |   |--- poutcome_failure <= 0.50
# |   |   |   |   |   |   |   |   |--- education_professional.course <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- education_professional.course >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- poutcome_failure >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cons.price.idx >  92.68
# |   |   |   |   |   |--- duration <= 392.50
# |   |   |   |   |   |   |--- contact_telephone <= 0.50
# |   |   |   |   |   |   |   |--- previous <= 2.50
# |   |   |   |   |   |   |   |   |--- euribor3m <= 0.89
# |   |   |   |   |   |   |   |   |   |--- day_of_week_mon <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 376.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- duration >  376.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- day_of_week_mon >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- education_high.school <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- education_high.school >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- euribor3m >  0.89
# |   |   |   |   |   |   |   |   |   |--- age <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- age >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- previous >  2.50
# |   |   |   |   |   |   |   |   |--- pdays <= 510.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- pdays >  510.00
# |   |   |   |   |   |   |   |   |   |--- education_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- education_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- contact_telephone >  0.50
# |   |   |   |   |   |   |   |--- housing_yes <= 0.50
# |   |   |   |   |   |   |   |   |--- job_admin. <= 0.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 254.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- duration >  254.00
# |   |   |   |   |   |   |   |   |   |   |--- month_jun <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- month_jun >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- job_admin. >  0.50
# |   |   |   |   |   |   |   |   |   |--- marital_divorced <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- month_may <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- month_may >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- marital_divorced >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- housing_yes >  0.50
# |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |--- job_entrepreneur <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx <= 94.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- cons.price.idx >  94.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- duration >  392.50
# |   |   |   |   |   |   |--- previous <= 2.50
# |   |   |   |   |   |   |   |--- euribor3m <= 1.04
# |   |   |   |   |   |   |   |   |--- previous <= 0.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 3135.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- duration >  3135.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- previous >  0.50
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- campaign <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- campaign >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- month_jul <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- month_jul >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- euribor3m >  1.04
# |   |   |   |   |   |   |   |   |--- job_management <= 0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 1.26
# |   |   |   |   |   |   |   |   |   |   |--- age <= 41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  41.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  1.26
# |   |   |   |   |   |   |   |   |   |   |--- loan_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- loan_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- job_management >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- previous >  2.50
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- duration >  1190.00
# |   |   |   |   |   |   |   |   |   |   |--- month_nov <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- month_nov >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |   |--- marital_married <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- marital_married >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- campaign >  6.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- euribor3m >  4.86
# |   |   |   |   |   |--- euribor3m <= 4.96
# |   |   |   |   |   |   |--- day_of_week_fri <= 0.50
# |   |   |   |   |   |   |   |--- duration <= 1240.00
# |   |   |   |   |   |   |   |   |--- duration <= 874.50
# |   |   |   |   |   |   |   |   |   |--- day_of_week_wed <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- day_of_week_wed >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- job_entrepreneur <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- duration >  874.50
# |   |   |   |   |   |   |   |   |   |--- housing_no <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- housing_no >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- age >  55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- duration >  1240.00
# |   |   |   |   |   |   |   |   |--- loan_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 4.93
# |   |   |   |   |   |   |   |   |   |   |--- housing_no <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- housing_no >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  4.93
# |   |   |   |   |   |   |   |   |   |   |--- job_admin. <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- job_admin. >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- loan_yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 4.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  4.86
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_thu >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- day_of_week_fri >  0.50
# |   |   |   |   |   |   |   |--- job_entrepreneur <= 0.50
# |   |   |   |   |   |   |   |   |--- age <= 28.00
# |   |   |   |   |   |   |   |   |   |--- month_may <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- month_may >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  28.00
# |   |   |   |   |   |   |   |   |   |--- age <= 56.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  56.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- euribor3m >  4.96
# |   |   |   |   |   |   |--- education_basic.4y <= 0.50
# |   |   |   |   |   |   |   |--- campaign <= 7.00
# |   |   |   |   |   |   |   |   |--- age <= 38.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  38.00
# |   |   |   |   |   |   |   |   |   |--- job_blue-collar <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 1673.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- duration >  1673.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- job_blue-collar >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- campaign >  7.00
# |   |   |   |   |   |   |   |   |--- marital_divorced <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- marital_divorced >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- education_basic.4y >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- contact_cellular >  0.50
# |   |   |   |   |--- month_nov <= 0.50
# |   |   |   |   |   |--- day_of_week_fri <= 0.50
# |   |   |   |   |   |   |--- month_jul <= 0.50
# |   |   |   |   |   |   |   |--- duration <= 1737.50
# |   |   |   |   |   |   |   |   |--- duration <= 846.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- duration >  846.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 928.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 1.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  1.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- duration >  928.50
# |   |   |   |   |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- duration >  1737.50
# |   |   |   |   |   |   |   |   |--- campaign <= 2.50
# |   |   |   |   |   |   |   |   |   |--- age <= 37.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- age >  37.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- campaign >  2.50
# |   |   |   |   |   |   |   |   |   |--- education_basic.4y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- education_basic.4y >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_jul >  0.50
# |   |   |   |   |   |   |   |--- duration <= 1914.50
# |   |   |   |   |   |   |   |   |--- education_basic.6y <= 0.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 1671.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 1576.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- duration >  1576.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- duration >  1671.00
# |   |   |   |   |   |   |   |   |   |   |--- job_services <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- job_services >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- education_basic.6y >  0.50
# |   |   |   |   |   |   |   |   |   |--- job_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m <= 4.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- euribor3m >  4.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- job_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- duration >  1914.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- day_of_week_fri >  0.50
# |   |   |   |   |   |   |--- job_entrepreneur <= 0.50
# |   |   |   |   |   |   |   |--- age <= 45.50
# |   |   |   |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |   |   |   |--- education_basic.4y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- age >  32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- education_basic.4y >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 888.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  888.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  45.50
# |   |   |   |   |   |   |   |   |--- month_aug <= 0.50
# |   |   |   |   |   |   |   |   |   |--- education_basic.6y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- housing_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- housing_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- education_basic.6y >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- month_aug >  0.50
# |   |   |   |   |   |   |   |   |   |--- job_self-employed <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- job_self-employed >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- job_entrepreneur >  0.50
# |   |   |   |   |   |   |   |--- cons.conf.idx <= -39.40
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cons.conf.idx >  -39.40
# |   |   |   |   |   |   |   |   |--- education_university.degree <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- education_university.degree >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- month_nov >  0.50
# |   |   |   |   |   |--- duration <= 1478.00
# |   |   |   |   |   |   |--- campaign <= 1.50
# |   |   |   |   |   |   |   |--- job_self-employed <= 0.50
# |   |   |   |   |   |   |   |   |--- duration <= 1037.50
# |   |   |   |   |   |   |   |   |   |--- previous <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 994.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  994.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- previous >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  38.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- duration >  1037.50
# |   |   |   |   |   |   |   |   |   |--- age <= 53.00
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_wed <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- day_of_week_wed >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- age >  53.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- job_self-employed >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- campaign >  1.50
# |   |   |   |   |   |   |   |--- duration <= 1047.50
# |   |   |   |   |   |   |   |   |--- job_admin. <= 0.50
# |   |   |   |   |   |   |   |   |   |--- job_management <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- job_management >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- poutcome_nonexistent >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- job_admin. >  0.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 4.14
# |   |   |   |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  4.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- duration >  1047.50
# |   |   |   |   |   |   |   |   |--- duration <= 1138.50
# |   |   |   |   |   |   |   |   |   |--- euribor3m <= 4.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- euribor3m >  4.05
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.4y <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- education_basic.4y >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- duration >  1138.50
# |   |   |   |   |   |   |   |   |   |--- duration <= 1208.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- duration >  1208.00
# |   |   |   |   |   |   |   |   |   |   |--- duration <= 1266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- duration >  1266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- duration >  1478.00
# |   |   |   |   |   |   |--- education_basic.9y <= 0.50
# |   |   |   |   |   |   |   |--- marital_single <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- marital_single >  0.50
# |   |   |   |   |   |   |   |   |--- job_technician <= 0.50
# |   |   |   |   |   |   |   |   |   |--- job_management <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- job_management >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- job_technician >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- education_basic.9y >  0.50
# |   |   |   |   |   |   |   |--- class: 0

# %% [markdown]
# **Đánh giá thuật toán Decision Tree:**
#
# Ưu điểm:
# -Mô hình sinh ra các quy tắc dễ hiểu cho người đọc, tạo ra bộ luật với mỗi nhánh lá là một luật của cây.
#
# -Có khả năng là việc với dữ liệu lớn
#
# -Có thể làm việc với cả dữ liệu số và dữ liệu phân loại
#
# Nhược điểm :
#
# -Mô hình cây quyết định phụ thuộc rất lớn vào dữ liệu của bạn. Thạm chí, với một sự thay đổi nhỏ trong bộ dữ liệu, cấu trúc mô hình cây quyết định có thể thay đổi hoàn toàn.
#
# -Cây quyết định hay gặp vấn đề overfitting

# %% [markdown]
# **naives bayes**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report
# Khởi tạo và huấn luyện mô hình Naive Bayes
model = GaussianNB()
model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đánh giá độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print(f"Độ chính xác của mô hình Naive Bayes là: {accuracy}")

# In báo cáo đánh giá chi tiết
print(classification_report(y_test, y_pred))
# Out:
# Độ chính xác của mô hình Naive Bayes là: 0.8646482635796973
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92     10929
#            1       0.43      0.53      0.47      1424
#
#     accuracy                           0.86     12353
#    macro avg       0.68      0.72      0.70     12353
# weighted avg       0.88      0.86      0.87     12353

# %% [markdown]
# đô chính xác của navies bayes là 0.8646482635796973

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
# Khởi tạo và huấn luyện mô hình Gaussian Naive Bayes
naive_bayes = GaussianNB()
naive_bayes.fit(X_train, y_train)

# Dự đoán kết quả
y_pred = naive_bayes.predict(X_test)

# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_test, y_pred)

# Hiển thị ma trận nhầm lẫn bằng biểu đồ heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# True Positive (số lượng các trường hợp dự đoán đúng là positive): là 9929
#
# False Positive (số lượng các trường hợp dự đoán sai là positive): là 1000
#
# False Negative (số lượng các trường hợp dự đoán sai là Negative): là 672
#
# True Negative (số lượng các trường hợp dự đoán đúng là Negative): là 752

# %% [markdown]
# **đánh giá thuật toán navies bayes:**
#
# Ưu điểm
#
# -hoạt động tốt cho nhiều bài toán/miền sữ liệu và ứng dụng.
#
# -Đơn giản nhưng đủ tốt để giải quyết nhiều bài toán như phân lớp văn bản, lọc spam,..
#
# -Huấn luyện mô hình (ước lượng tham số) dễ và nhanh.
#
# Nhược điểm
#
# -Vấn đề zero
#
# -Mô hình không được huẩn luyện bằng phượng pháp tối ưu mạnh và chặt chẽ.
#
# -Tham số mủa mô hình là các ước lượng xác suất điều kiện đơn lẻ.

# %% [markdown]
# **Random forest**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

X = pd.get_dummies(X)

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Huấn luyện mô hình trên tập dữ liệu huấn luyện
rf.fit(X_train, y_train)

# Dự đoán nhãn cho tập dữ liệu test
predictions = rf.predict(X_test)

# Đánh giá độ chính xác và hiển thị báo cáo
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.9110337569821096
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10929
#            1       0.67      0.44      0.53      1424
#
#     accuracy                           0.91     12353
#    macro avg       0.80      0.71      0.74     12353
# weighted avg       0.90      0.91      0.90     12353

# %% [markdown]
# độ chính xác của Random forest là : 0.9110337569821096

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Khởi tạo mô hình Random Forest
rf = RandomForestClassifier()

# Huấn luyện mô hình trên tập huấn luyện
rf.fit(X_train, y_train)

# Dự đoán nhãn cho tập kiểm tra
y_pred = rf.predict(X_test)

# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_test, y_pred)

# Hiển thị ma trận nhầm lẫn bằng biểu đồ heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# True Positive (số lượng các trường hợp dự đoán đúng là positive): là 10639
#
# False Positive (số lượng các trường hợp dự đoán sai là positive): là 290
#
# False Negative (số lượng các trường hợp dự đoán sai là Negative): là 809
#
# True Negative (số lượng các trường hợp dự đoán đúng là Negative): là 615

# %% [markdown]
# **Đánh giá thuật toán Random forest**
#
# *Ưu điểm:
#
# -Random Forest có khả năng thực hiện cả hai nhiệm vụ Phân loại và Hồi quy.
#
# -Nó có khả năng xử lý các tập dữ liệu lớn với kích thước cao.
#
# -Nó nâng cao độ chính xác của mô hình và ngăn chặn vấn đề trang bị quá mức.
#
# *Nhược điểm:
#
# -Overfitting: Nếu số lượng cây quản lí lùi trở lại quá lớn, Random Forest có thể overfit dữ liệu, làm cho nó không có khả năng dự đoán cho dữ liệu mới.
#
# -Quá nhiều cây: Random Forest là một học máy kết hợp nhiều cây quản lí lùi trở lại, với một số cây trong quá trình học. Như vậy, nó có thể tốn nhiều tài nguyên và thời gian để xây dựng và quản lý một lớp cây.
#
# -Memory usage: Random Forest có tầm nhìn rất lớn, do đó, nó có thể tiêu dung memory lớn khi xử lý dữ liệu. Nếu dữ liệu có kích thước lớn, Random Forest có thể gây ra lỗi do memory overflow.
#
# -Interpretability: Do Random Forest là một học máy kết hợp ngẫu nhiên, không có cách rõ ràng để giải thíêt biến chính xác, vì nó sẽ chọn một số biến khác nhau từ mỗi cây.
#
# -Sensitivity to missing values: Random Forest có khản cứng đối với dữ liệu bị thiếu, vì nó sẽ chọn một số cây khác nhau từ dữ liệu, và một số cây có thể bị ảnh hưởng nặng bởi dữ liệu bị thiếu.

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression # Thư viện LogisticRegression trong sklearn
from sklearn.metrics import classification_report   # classification_report: dánh giá mô hình

# %%
def log_reg(x_train,y_train,x_test,y_test):
  model = LogisticRegression()                  # Gán LogisticRegression cho 1 biến model

  model.fit(x_train,y_train)                    # Tính toán dữ liệu

  acc = model.score(x_test,y_test)              # Xem tập dữ liệu test có độ chính xác bao nhiêu %
  print("Độ chính xác",acc,"\n")

  y_pred = model.predict(x_test)                # predict : du doan
  print("Dự đoán",y_pred[:5],"\n")

  cl_rep = classification_report(y_test,y_pred) # Kết quả sẽ được lưu trong biến `cl_rep`
  print(cl_rep)

# %%
log_reg(X_train,y_train,X_test,y_test)
# Out:
# Độ chính xác 0.9076337731725087
#
# Dự đoán [1 0 0 0 0]
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10929
#            1       0.67      0.40      0.50      1424
#
#     accuracy                           0.91     12353
#    macro avg       0.80      0.69      0.72     12353
# weighted avg       0.90      0.91      0.90     12353
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Độ chính xác của thuật toán Logistic Regression là :0.9076337731725087

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Khởi tạo mô hình Logistic Regression
logreg = LogisticRegression()

# Huấn luyện mô hình trên toàn bộ dữ liệu
logreg.fit(X, y)

# Dự đoán nhãn cho tập kiểm tra
y_pred = logreg.predict(X_test)

# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_test, y_pred)

# Hiển thị ma trận nhầm lẫn bằng biểu đồ heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# True Positive (số lượng các trường hợp dự đoán đúng là positive): là 10628
#
# False Positive (số lượng các trường hợp dự đoán sai là positive): là 301
#
# False Negative (số lượng các trường hợp dự đoán sai là Negative): là 850
#
# True Negative (số lượng các trường hợp dự đoán đúng là Negative): là 574

# %% [markdown]
# **Đánh giá thuật toán Logistic Regression**
#
# Ưu điểm:
#
# -Dễ hiểu và dễ triển khai: Logistic Regression là một mô hình đơn giản và dễ hiểu, có thể được triển khai một cách nhanh chóng.
#
# -Hiệu suất tốt với dữ liệu tuyến tính hóa: Khi dữ liệu tuyến tính hóa (linearly separable), Logistic Regression có thể cho kết quả tốt.
#
# -Cung cấp xác suất dự đoán: Logistic Regression có thể cung cấp xác suất dự đoán thuộc vào mỗi lớp, chứ không chỉ là việc dự đoán lớp.
#
# -Không yêu cầu dữ liệu lớn: Thuật toán có thể hoạt động tốt với các tập dữ liệu nhỏ hoặc có ít đặc trưng.
#
# -Khả năng tùy chỉnh ngưỡng quyết định: Bằng cách thay đổi ngưỡng xác suất, người dùng có thể điều chỉnh giữa độ chính xác và độ nhạy cảm của mô hình.
#
# Nhược điểm:
#
# -Yêu cầu các điều kiện giả định: Logistic Regression yêu cầu dữ liệu phải thỏa mãn một số điều kiện giả định như tuyến tính hóa, không có nhiễu lớn, và không có đa cộng tuyến nghiêm trọng.
#
# -Không xử lý được tương quan cao: Nếu có tương quan cao giữa các đặc trưng, Logistic Regression có thể không hoạt động hiệu quả.
#
# -Không phù hợp với dữ liệu phi tuyến tính: Trong trường hợp dữ liệu không thể tuyến tính hóa, Logistic Regression có thể không cung cấp kết quả tốt.
#
# -Dễ bị ảnh hưởng bởi outliers: Các điểm dữ liệu ngoại lai (outliers) có thể ảnh hưởng đáng kể đến mô hình Logistic Regression.
